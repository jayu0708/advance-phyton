# %% [markdown]
# ## inheritance

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## child class will inherit the attributes and methods from parent class

# %%
class Person:

    def __init__(self, name, age) -> None:
        self.name = name
        self.age = age 

    def introduce(self):
        print(f"Hi there my name is {self.name}")
        print(f"I am currently {self.age} years old")

# %%
class Employee(Person):

    def __init__(self, name, age, company) -> None:
        super().__init__(name, age)
        self.company = company

    def work(self):
        print(f"I work for {self.company}")

# %%
p1 =Person(name="amol",age=44)

# %%
p1.name
# Out:
# 'amol'

# %%
p1.age
# Out:
# 44

# %%
p1.introduce()
# Out:
# Hi there my name is amol
# I am currently 44 years old

# %%
type(p1)
# Out:
# __main__.Person

# %%
e1 =Employee(name="Raman",age=33,company="infosys")
type(e1)
# Out:
# __main__.Employee

# %%
e1.name
# Out:
# 'Raman'

# %%
e1.age
# Out:
# 33

# %%
e1.company
# Out:
# 'infosys'

# %%
e1.work()
# Out:
# I work for infosys

# %%
e1.introduce()
# Out:
# Hi there my name is Raman
# I am currently 33 years old

# %%
e1.introduce()
e1.work()
# Out:
# Hi there my name is Raman
# I am currently 33 years old
# I work for infosys

# %% [markdown]
# ## pydantic for data validation

# %%
# %pip install pydantic email-validator
# Out:
# Collecting pydantic
#   Downloading pydantic-2.9.2-py3-none-any.whl.metadata (149 kB)
# Collecting email-validator
#   Downloading email_validator-2.2.0-py3-none-any.whl.metadata (25 kB)
# Collecting annotated-types>=0.6.0 (from pydantic)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.23.4 (from pydantic)
#   Downloading pydantic_core-2.23.4-cp312-none-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: typing-extensions>=4.6.1 in e:\advance python  class\repository\venv\lib\site-packages (from pydantic) (4.12.2)
# Collecting dnspython>=2.0.0 (from email-validator)
#   Downloading dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: idna>=2.0.0 in e:\advance python  class\repository\venv\lib\site-packages (from email-validator) (3.9)
# Downloading pydantic-2.9.2-py3-none-any.whl (434 kB)
# Downloading pydantic_core-2.23.4-cp312-none-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.9 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.9 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.9 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/1.9 MB 372.9 kB/s eta 0:00:04
#    ---------- ----------------------------- 0.5/1.9 MB 372.9 kB/s eta 0:00:04
#    ---------- ----------------------------- 0.5/1.9 MB 372.9 kB/s eta 0:00:04
#    ---------- ----------------------------- 0.5/1.9 MB 372.9 kB/s eta 0:00:04
#    ---------------- ----------------------- 0.8/1.9 MB 349.5 kB/s eta 0:00:04
#    ---------------- ----------------------- 0.8/1.9 MB 349.5 kB/s eta 0:00:04
#    ---------------- ----------------------- 0.8/1.9 MB 349.5 kB/s eta 0:00:04
#    --------------------- ------------------ 1.0/1.9 MB 372.9 kB/s eta 0:00:03
#    --------------------- ------------------ 1.0/1.9 MB 372.9 kB/s eta 0:00:03
#    --------------------------- ------------ 1.3/1.9 MB 387.9 kB/s eta 0:00:02
#    --------------------------- ------------ 1.3/1.9 MB 387.9 kB/s eta 0:00:02
#    --------------------------- ------------ 1.3/1.9 MB 387.9 kB/s eta 0:00:02
#    -------------------------------- ------- 1.6/1.9 MB 399.5 kB/s eta 0:00:01
#    -------------------------------------- - 1.8/1.9 MB 432.1 kB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 439.8 kB/s eta 0:00:00
# Downloading email_validator-2.2.0-py3-none-any.whl (33 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
# Installing collected packages: pydantic-core, dnspython, annotated-types, pydantic, email-validator
# Successfully installed annotated-types-0.7.0 dnspython-2.6.1 email-validator-2.2.0 pydantic-2.9.2 pydantic-core-2.23.4
# Note: you may need to restart the kernel to use updated packages.

# %%
from pydantic import BaseModel, Field, EmailStr

# %%
from typing import List

# %%
from datetime import date

# %%
date.today()
# Out:
# datetime.date(2024, 9, 21)

# %%
class Student(BaseModel):

    roll_no: int = Field(description="Roll Number of student", gt=0)
    name: str = Field(description="Name of the student", min_length=3)
    email: EmailStr = Field(description="Email for student")
    hobbies: List[str] = Field(description="Student Hobbies", default_factory=list)
    doj: date = Field("Date of Joining", le=date.today())

    def get_student_info(self):
        print(f"Roll Number : {self.roll_no}")
        print(f"Name : {self.name}")
        print(f"Email : {self.email}")
        print(f"Hobbies : {self.hobbies}")
        print(f"Date of Joining : {self.doj}")

# %%
s1 = Student(
    roll_no=101,
    name = "rahul",
    email = "example@test.com",
    hobbies=["singing","criket"],
    doj =date(2024,5,13)
)

# %%
s1
# Out:
# Student(roll_no=101, name='rahul', email='example@test.com', hobbies=['singing', 'criket'], doj=datetime.date(2024, 5, 13))

# %%
s1.roll_no
# Out:
# 101

# %%
s1.name
# Out:
# 'rahul'

# %%
s1.email
# Out:
# 'example@test.com'

# %%
s1.hobbies
# Out:
# ['singing', 'criket']

# %%
s1.doj
# Out:
# datetime.date(2024, 5, 13)

# %%
s1.get_student_info()
# Out:
# Roll Number : 101
# Name : rahul
# Email : example@test.com
# Hobbies : ['singing', 'criket']
# Date of Joining : 2024-05-13

# %%
s2 =Student(
roll_no=67.8,
name ="",
email ="example",
hobbies = "singing",
doj ="23rd jan 2024"
)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 s2 =Student(
#       2 roll_no=67.8,
#       3 name ="",
#       4 email ="example",
#       5 hobbies = "singing",
#       6 doj ="23rd jan 2024"
#       7 )
#
# File e:\advance python  class\repository\venv\Lib\site-packages\pydantic\main.py:212, in BaseModel.__init__(self, **data)
#     210 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     211 __tracebackhide__ = True
# --> 212 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     213 if self is not validated_self:
#     214     warnings.warn(
#     215         'A custom validator is returning a value other than `self`.\n'
#     216         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     217         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     218         category=None,
#     219     )
#
# ValidationError: 5 validation errors for Student
# roll_no
#   Input should be a valid integer, got a number with a fractional part [type=int_from_float, input_value=67.8, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.9/v/int_from_float
# name
#   String should have at least 3 characters [type=string_too_short, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.9/v/string_too_short
# email
#   value is not a valid email address: An email address must have an @-sign. [type=value_error, input_value='example', input_type=str]
# hobbies
#   Input should be a valid list [type=list_type, input_value='singing', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.9/v/list_type
# doj
#   Input should be a valid date or datetime, invalid character in year [type=date_from_datetime_parsing, input_value='23rd jan 2024', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.9/v/date_from_datetime_parsing

# %% [markdown]
# ## multilevel inheritance

# %%
class Employee2:

    def __init__(self, emp_id, name) -> None:
        self.emp_id = emp_id
        self.name = name 

    def get_employee_info(self):
        print(f"Employee id : {self.emp_id}")
        print(f"Name : {self.name}")

# %%
class Manager(Employee2):

    def __init__(self, emp_id, name, dept) -> None:
        super().__init__(emp_id, name)
        self.dept = dept

    def get_manger_info(self):
        print(f"Departement : {self.dept}")

# %%
class ProjectManager(Manager):

    def __init__(self, emp_id, name, dept, project) -> None:
        super().__init__(emp_id, name, dept)
        self.project = project

    def get_project_info(self):
        print(f"Project Name : {self.project}")

# %%
e2 = Employee2(emp_id=103, name="Sarthak")
type(e2)
# Out:
# __main__.Employee2

# %%
e2.emp_id
# Out:
# 103

# %%
e2.name
# Out:
# 'Sarthak'

# %%
e2.get_employee_info()
# Out:
# Employee id : 103
# Name : Sarthak

# %%
m2 = Manager(emp_id=102,name="Rahul",dept="Engg.")
print(type(m2))
print(m2.emp_id)
# Out:
# <class '__main__.Manager'>
# 102

# %%
m2.dept
# Out:
# 'Engg.'

# %%
m2.name
# Out:
# 'Rahul'

# %%
m2.get_employee_info()
m2.get_manger_info()
# Out:
# Employee id : 102
# Name : Rahul
# Departement : Engg.

# %%
pm2 = ProjectManager(emp_id=101,name="Raman",dept="Engg.",project="Tesla")
type(pm2)
# Out:
# __main__.ProjectManager

# %%
pm2.emp_id
# Out:
# 101

# %%
pm2.name
# Out:
# 'Raman'

# %%
pm2.dept
# Out:
# 'Engg.'

# %%
pm2.project
# Out:
# 'Tesla'

# %%
pm2.get_employee_info()
pm2.get_manger_info()
pm2.get_project_info()
# Out:
# Employee id : 101
# Name : Raman
# Departement : Engg.
# Project Name : Tesla

# %% [markdown]
# ## hierarchical inhertance

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class user:
    def __init__(self,id,username,email) ->None:
        self.id =id
        self.username = username
        self.email = email
    def get_user_info(self):
        print(f"user id :{self.id}")
        print(f"username : {self.username}")
        print(f"self.email")

# %%
class AdminUser(user):
    def __init__(self, id, username, email, access) -> None:
        super().__init__(id, username, email)
        self.access = access

    def get_access_level(self):
        print(f"Access : {self.access}")

# %%
class RegularUser(user):

    def __init__(self, id, username, email, sub) -> None:
        super().__init__(id, username, email)
        self.sub = sub

    def get_sub_type(self):
        print(f"Subscription Type : {self.sub}")

# %%
u1 = user(id=1, username="utkarsh1", email="utkarh@gmail.com")
type(u1)
# Out:
# __main__.user

# %%
u1.id
# Out:
# 1

# %%
u1.username
# Out:
# 'utkarsh1'

# %%
u1.email
# Out:
# 'utkarh@gmail.com'

# %%
u1.get_user_info()
# Out:
# user id :1
# username : utkarsh1
# self.email

# %%
a1 = AdminUser(id=2, username="Sam", email="sam@test.com", access="partial")
type(a1)
# Out:
# __main__.AdminUser

# %%
a1.id
# Out:
# 2

# %%
a1.username
# Out:
# 'Sam'

# %%
a1.access
# Out:
# 'partial'

# %%
a1.get_user_info()
a1.get_access_level()
# Out:
# user id :2
# username : Sam
# self.email
# Access : partial

# %%
r1 = RegularUser(id=3, username="John", email="john@test.com", sub="paid-yearly")
type(r1)
# Out:
# __main__.RegularUser

# %%
r1 .id
# Out:
# 3

# %%
r1.username
# Out:
# 'John'

# %%
r1.email
# Out:
# 'john@test.com'

# %%
r1.sub
# Out:
# 'paid-yearly'

# %%
r1.get_user_info()
r1.get_sub_type()
# Out:
# user id :3
# username : John
# self.email
# Subscription Type : paid-yearly

# %%
r1.get_access_level()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 r1.get_access_level()
#
# AttributeError: 'RegularUser' object has no attribute 'get_access_level'

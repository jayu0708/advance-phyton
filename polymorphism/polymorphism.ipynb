# %% [markdown]
# polymorphism

# %% [markdown]
# student assignment
# create class triangle with 3 sides

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
25**(1/2)
# Out:
# 5.0

# %%
64**(1/2)
# Out:
# 8.0

# %% [markdown]
# 1. sum of any two sides should always be greater than third

# %%
from dataclasses import dataclass
from typing import Union

# %%
@dataclass
class Triangle:

    a: Union[int, float]
    b: Union[int, float]
    c: Union[int, float]

    def __post_init__(self):
        errors = []

        if not isinstance(self.a, (int, float)) or self.a <= 0:
            errors.append("Side a should be positive int or float")
        if not isinstance(self.b, (int, float)) or self.b <= 0:
            errors.append("Side b shoule be positive int or float")
        if not isinstance(self.c, (int, float)) or self.c <= 0:
            errors.append("Side c should be positive int or float")
        if not self.is_triangle():
            errors.append("Sum of any two sides should always be greater than third")

        if errors:
            raise ValueError("\n".join(errors))

    def is_triangle(self):
        if (
            (self.a + self.b > self.c)
            and (self.b + self.c > self.a)
            and (self.c + self.a > self.b)
        ):
            return True
        else:
            return False

    def perimeter(self):
        return self.a + self.b + self.c

    def area(self):
        s = self.perimeter() / 2
        return (s * (s - self.a) * (s - self.b) * (s - self.c)) ** (1 / 2)

# %%
t1 = Triangle(3, 4, 5)

# %%
t1 = Triangle(a=3,b=4,c=5)

# %%
t1.a
# Out:
# 3

# %%
t1.b
# Out:
# 4

# %%
t1.c
# Out:
# 5

# %%
t1.is_triangle()
# Out:
# True

# %%
t1.perimeter()
# Out:
# 12

# %%
t1.area()
# Out:
# 6.0

# %%
t2 = Triangle(False, 3, 4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 t2 = Triangle(False, 3, 4)
#
# File <string>:6, in __init__(self, a, b, c)
#
# Cell In[18], line 21, in Triangle.__post_init__(self)
#      18     errors.append("Sum of any two sides should always be greater than third")
#      20 if errors:
# ---> 21     raise ValueError("\n".join(errors))
#
# ValueError: Side a should be positive int or float
# Sum of any two sides should always be greater than third

# %%
t2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 t2
#
# NameError: name 't2' is not defined

# %%
t2 = Triangle(1,2,4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 t2 = Triangle(1,2,4)
#
# File <string>:6, in __init__(self, a, b, c)
#
# Cell In[18], line 21, in Triangle.__post_init__(self)
#      18     errors.append("Sum of any two sides should always be greater than third")
#      20 if errors:
# ---> 21     raise ValueError("\n".join(errors))
#
# ValueError: Sum of any two sides should always be greater than third

# %%
t2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 t2
#
# NameError: name 't2' is not defined

# %%
t2 = Triangle(12,13,14.5)

# %%
t2
# Out:
# Triangle(a=12, b=13, c=14.5)

# %%
t2.perimeter()
# Out:
# 39.5

# %%
t2.area()
# Out:
# 73.64884482291626

# %%
print(type(t2))
# Out:
# <class '__main__.Triangle'>

# %% [markdown]
# polymorphism

# %% [markdown]
# # polymorphism in functions

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = "ETLHive"
type(a)
# Out:
# str

# %%
len(a)
# Out:
# 7

# %%
b=["a","b","d","e"]
type (b)
# Out:
# list

# %%
len(b)
# Out:
# 4

# %%
c=(1,2,3,4,5,6,7)
print(type(c))
print(len(c))
# Out:
# <class 'tuple'>
# 7

# %%
d = {"name":"jayshri",
     "age":56,
     "email":"jayshri9897@gmail.com"
     }
print(type(d))
print(len(d))
# Out:
# <class 'dict'>
# 3

# %%
for  i in (a,b,c,d):
    print(i)
    print(len(i))
    print(type(i))
    print("\n+++++++++++++++++++++++++++++++\n")
# Out:
# ETLHive
# 7
# <class 'str'>
#
# +++++++++++++++++++++++++++++++
#
# ['a', 'b', 'd', 'e']
# 4
# <class 'list'>
#
# +++++++++++++++++++++++++++++++
#
# (1, 2, 3, 4, 5, 6, 7)
# 7
# <class 'tuple'>
#
# +++++++++++++++++++++++++++++++
#
# {'name': 'jayshri', 'age': 56, 'email': 'jayshri9897@gmail.com'}
# 3
# <class 'dict'>
#
# +++++++++++++++++++++++++++++++

# %%
for i in (a, b, c, d):
    print(i)
    print(type(i))
    print(len(i))
    print("/n=====================================/n")
# Out:
# ETLHive
# <class 'str'>
# 7
# /n=====================================/n
# ['a', 'b', 'd', 'e']
# <class 'list'>
# 4
# /n=====================================/n
# (1, 2, 3, 4, 5, 6, 7)
# <class 'tuple'>
# 7
# /n=====================================/n
# {'name': 'jayshri', 'age': 56, 'email': 'jayshri9897@gmail.com'}
# <class 'dict'>
# 3
# /n=====================================/n

# %% [markdown]
# ### polymorphism in operators

# %%
3+5
# Out:
# 8

# %%
5.5+6.6
# Out:
# 12.1

# %%
"str1"
# Out:
# 'str1'

# %%
"str1"+"str2"
# Out:
# 'str1str2'

# %%
[0,9,8,7,6,5,5]+[1,2,3,4,5]
# Out:
# [0, 9, 8, 7, 6, 5, 5, 1, 2, 3, 4, 5]

# %% [markdown]
# # polymorphism in classes

# %%
class India:

    def capital(self):
        print("New Delhi is Captial of India")

    def language(self):
        print("Hindi is widely spoken in India")

# %%
class USA:

    def capital(self):
        print("Washington D.C. is capital of USA")

    def language(self):
        print("English is widely spoken in USA")

# %%
class France:

    def capital(self):
        print("Paris is capital of France")

    def language(self):
        print("French is widely spoken in France")

# %%
c1 = India()
type(c1)
# Out:
# __main__.India

# %%
c2 = USA()
type(c2)
# Out:
# __main__.USA

# %%
c3=France()
type(c3)
# Out:
# __main__.France

# %%
c1.capital()
# Out:
# New Delhi is Captial of India

# %%
c1.language()
# Out:
# Hindi is widely spoken in India

# %%
c3.capital()
# Out:
# Paris is capital of France

# %%
c3.language()
# Out:
# French is widely spoken in France

# %%
for i in (c1,c2,c3):
    print(type(i))
    i.capital()
    i.language()
    print("\n++++++++++++++++++\n")
# Out:
# <class '__main__.India'>
# New Delhi is Captial of India
# Hindi is widely spoken in India
#
# ++++++++++++++++++
#
# <class '__main__.USA'>
# Washington D.C. is capital of USA
# English is widely spoken in USA
#
# ++++++++++++++++++
#
# <class '__main__.France'>
# Paris is capital of France
# French is widely spoken in France
#
# ++++++++++++++++++

# %% [markdown]
# # creating area and perimeter for different shapes

# %%
@dataclass
class Rectangle:

    width: Union[int, float]
    height: Union[int, float]

    def perimeter(self):
        return 2*(self.width + self.height)
    
    def area(self):
        return self.width * self.height

# %%
from math import pi
pi
# Out:
# 3.141592653589793

# %%
@dataclass
class Circle:

    radius: Union[int, float]

    def perimeter(self):
        return 2*pi*self.radius
    
    def area(self):
        return pi*(self.radius**2)

# %%
s1 = Rectangle(30, 40)
s2 = Circle(14)
s3 = Triangle(12, 13, 14)
s4 = Circle(20)
s5 = Rectangle(10, 12)

# %%
for i in (s1,s2,s3,s4,s5):
    print(type(i))
    print(f"perimeter : {i.perimeter():4f}")
    print(f"Area :{i.area():.4f}")
    print("\n===========\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 for i in (s1,s2,s3,s4,s5):
#       2     print(type(i))
#       3     print(f"perimeter : {i.perimeter():4f}")
#
# NameError: name 's1' is not defined
